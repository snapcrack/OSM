# %%
#preliminary necessities
import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

philly = "philadelphia_pennsylvania.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "philadelphia_pennsylvania.osm"  # Replace this with your osm file
SAMPLE_FILE = "sample.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
#counting the number of tags in the file
def count_tags(filename):
    tags = {}
    for i, element in enumerate(get_element(filename)):
        if element.tag not in tags.keys():
            tags[element.tag] = 1
        else:
            tags[element.tag] += 1
    return tags

# %%
count_tags(SAMPLE_FILE)
# Out:
# {'node': 302379, 'relation': 474, 'way': 30493}

# %%
count_tags(philly)
# Out:
# {'node': 3023787, 'relation': 4742, 'way': 304928}

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter("tag"):
            if lower.search(tag.attrib['k']):
               keys['lower'] += 1
            elif lower_colon.search(tag.attrib['k']):
               keys['lower_colon'] += 1
            elif problemchars.search(tag.attrib['k']):
               keys['problemchars'] += 1
            elif street_type_re.search(tag.attrib['k']):
                keys['street_type'] += 1
            else:
               keys['other'] += 1
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0, "street_type": 0}
    for element in get_element(filename, tags=('node', 'way')):
        keys = key_type(element, keys)

    return keys
    '''

def process_map(filename):
    keys = {"lower": {}, "lower_colon": {}, "problemchars": {}, "other": {}}    
    
    context = iter(ET.iterparse(filename, events=('start', 'end')))
    _, root = next(context)
    for event, element in context:
        if event == 'start':  
            keys = key_type(element, keys)
        elif event == 'end':
            root.clear()

    return keys
    '''

# %%
keys = process_map(philly)
pprint.pprint(keys)
# Out:
# {'lower': 0, 'lower_colon': 0, 'other': 0, 'problemchars': 0, 'street_type': 0}

# %%
#audit to see what needs cleaning
from collections import defaultdict

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

#function to fix memory issues in auditing the full OSM file
def get_element(osm_file, tags=('node', 'way')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

#postcode stuff
def is_postcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_postcode(postcodes, postcode):
    p = re.match(r'^\d{5}$', postcode)
    #postcodes = defaultdict(set)
    if p:
        return postcode
    else:
        postcodes[postcode].add(postcode)
        
#audit

def audit(osmfile):
    street_types = defaultdict(set)
    ### the 'postcodes' dictionary is created only once here:
    postcodes = defaultdict(set)
    # loop over every element in the file 'osm_file'
    ### use 'get_element()' here (instead of '.iterparse()':
    for elem in get_element(osmfile):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
                elif is_postcode(tag):
                    audit_postcode(postcodes, tag.attrib['v'])
    #osm_file.close()
    return street_types, postcodes

# %%
audit(SAMPLE_FILE)
# Out:
# (defaultdict(set,
#              {'1': {'Sansom St #1'},
#               '111': {'South Clinton Avenue Ste. 111'},
#               '38': {'Route 38', 'State Route 38'},
#               '452': {'Pennel Road; Pennsylvania Route 452'},
#               '70': {'State Route 70', 'US 70'},
#               '73': {'State Route 73'},
#               'Alley': {'Elfreths Alley'},
#               'Ave': {'Chester Ave',
#                'Cottman Ave',
#                'Essington Ave',
#                'Fort Washington Ave',
#                'Germantown Ave',
#                'Grant Ave',
#                'Lancaster Ave',
#                'Montgomery Ave',
#                'Philmont Ave',
#                'S Clinton Ave',
#                'Sharon Ave',
#                'Summit Ave'},
#               'Ave.': {'Bonny Brook Ave.', 'Morton Ave.'},
#               'Bigler': {'Bigler'},
#               'Blvd': {'Garden Gold Blvd',
#                'Hearthstone Blvd',
#                'S Christopher Columbus Blvd',
#                'W Cuthbert Blvd'},
#               'Broadway': {'South Broadway'},
#               'Center': {'Town Center'},
#               'Chestnut': {'Chestnut'},
#               'Cir': {'Woodfield Cir'},
#               'Circle': {'College Circle',
#                'Crestview Circle',
#                'Falcon Circle',
#                'Hanby Circle',
#                'Nolen Circle',
#                'Shirley Circle',
#                'Tara Circle',
#                'Wynnedale Circle'},
#               'Croft': {'Kings Croft'},
#               'Crossing': {'Harpers Crossing'},
#               'Dr': {"Tommy's Meadow Dr"},
#               'East': {'Clementon Road East',
#                'High Street East',
#                'Lincoln Drive East',
#                'Marlton Pike East'},
#               'Extension': {'Spruce Street Extension'},
#               'Haverford': {'Haverford'},
#               'Highway': {'East Lincoln Highway',
#                'Lincoln Highway',
#                'North Kings Highway'},
#               'Hwy': {'Harding Hwy'},
#               'Ln': {'Simpkins Ln'},
#               'Manor': {'Brynwood Manor'},
#               'North': {'Delsea Drive North', 'Lakeview Drive North'},
#               'PA': {'Baltimore Pike, Springfield, PA'},
#               'Park': {'Narbrook Park'},
#               'Pike': {'Baltimore Pike',
#                'Bethlehem Pike',
#                'Brunswick Pike',
#                'Butler Pike',
#                'Concord Pike',
#                'East Germantown Pike',
#                'Limekiln Pike',
#                'Marlton Pike',
#                'Princeton Pike',
#                'Sumneytown Pike',
#                'West Chester Pike',
#                'West Germantown Pike',
#                'West Ridge Pike',
#                'White Horse Pike'},
#               'Plaza': {'Dothan Plaza'},
#               'Rd': {"Arney's Mount Rd",
#                'Clements Bridge Rd',
#                'Conestoga Rd',
#                'Cross Keys Rd',
#                'Darby Rd',
#                'Easton Rd',
#                'Hurffville Rd'},
#               'Rd.': {'Kagey Rd.'},
#               'Run': {'Autumn River Run', 'Pheasant Run'},
#               'South': {'Lakeview Drive South'},
#               'St': {'Cooper St',
#                'E Hampton St',
#                'E State St',
#                'Green St',
#                'N 4th St',
#                'N Main St',
#                'Race St',
#                'Rhawn St',
#                'S 47th St',
#                'S Broad St',
#                'Spring Garden St'},
#               'St.': {'Diamond St.', 'South Broad St.'},
#               'StreetPhiladelphia': {'117 South 18th StreetPhiladelphia'},
#               'Terrace': {'Alfa Terrace',
#                'Dothan Terrace',
#                'Elm Terrace',
#                'Lakeview Terrace'},
#               'Thompson': {'Sletcher and Thompson'},
#               'Vine': {'12th and Vine'},
#               'Walk': {'Locust Walk'},
#               'Way': {'Azalea Way',
#                'Bellows Way',
#                'Green Valley Way',
#                'Janton Way',
#                'Jennifer Way',
#                'Lafrance Way',
#                'Lucretia Mott Way',
#                'Mather Way',
#                'Plaza Way',
#                'Winston Way',
#                'Woodview Way'},
#               'West': {'North Independence Mall West'},
#               'al': {'pullen al'},
#               'ave': {'Ridge ave', 'michigan ave'},
#               'avenue': {'Ohio avenue'},
#               'ext': {'brunswick ave ext'},
#               'south': {'Route 130 south'},
#               'st': {'clay st',
#                'e front st',
#                'jackson st',
#                'mercer st',
#                'pear st',
#                's broad st',
#                's stockton st',
#                'w state st'}}),
#  defaultdict(set,
#              {'0815': {'0815'},
#               '1719': {'1719'},
#               '601 Stokes Road Medford, NJ 08055': {'601 Stokes Road Medford, NJ 08055'}}))

# %%
audit(philly)
# Out:
# (defaultdict(set,
#              {'1': {'Route 1',
#                'S Newtown Street Rd #1',
#                'Sansom St #1',
#                'Walnut St #1'},
#               '111': {'South Clinton Avenue Ste. 111'},
#               '118': {'Upland Ave #118'},
#               '168': {'Marlton Pike East Ste. 168'},
#               '17': {'Lancaster Avenue #17'},
#               '19047': {'200 Manor Ave. Langhorne, PA 19047',
#                '2245 E. Lincoln Hwy, Langhorne, PA 19047',
#                '2275 E Lincoln Hwy, Langhorne, PA 19047',
#                '2300  East Lincoln Highway, Pennsylvania 19047'},
#               '19067': {'East Trenton Avenue Morrisville, PA 19067'},
#               '2': {'Buck Rd #2'},
#               '205': {'Office Center Dr #205'},
#               '206': {'US 206', 'US 70 & US 206'},
#               '3': {'Main St #3'},
#               '315': {'Heritage Center Dr #315'},
#               '33': {'33', 'Route 33'},
#               '37th': {'N 37th'},
#               '38': {'New Jersey 38', 'Route 38', 'State Route 38'},
#               '39th': {'N 39th'},
#               '40': {'1140 US Highway 40', 'Rt 40'},
#               '4080': {'4080'},
#               '41st': {'S. 41st'},
#               '43rd': {'N 43rd'},
#               '446-1234': {'1 Brookline BlvdHavertown, PA 19083(610) 446-1234'},
#               '452': {'Market Street; Pennsylvania Route 452',
#                'Pennel Road; Pennsylvania Route 452'},
#               '5': {'West Girard Avenue, 5'},
#               '53rd': {'N 53rd'},
#               '611': {'Easton Road Route 611'},
#               '651': {'W Ridge Pike #651'},
#               '70': {'State Route 70', 'US 70'},
#               '73': {'New Jersey 73',
#                'North Route 73',
#                'Route 73',
#                'State Route 73'},
#               '80': {'N Lewis RD Unit #80'},
#               '902': {'Chestnut Street #902'},
#               'A': {'S Bethlehem Pike #A'},
#               'AVE': {'EDGMONT AVE'},
#               'Alley': {'Bradford Alley',
#                'Elfreths Alley',
#                'Horners Alley',
#                'Willings Alley'},
#               'Atreet': {'Arch Atreet'},
#               'Ave': {'517 W Girard Ave',
#                '72nd Ave and Orgontz Ave',
#                '8401 Frankford Ave',
#                'Alden Ave',
#                'Aramingo Ave',
#                'Bala Ave',
#                'Baltimore Ave',
#                'Bishop Ave, Clifton Ave',
#                'Bryn Mawr Ave',
#                'Chester Ave',
#                'Constitution Ave',
#                'Cottman Ave',
#                'Devon St & Mt. Pleasant Ave',
#                'E Butler Ave',
#                'E Lancaster Ave',
#                'E. Mt Airy Ave',
#                'East Lancaster Ave',
#                'East Wadsworth Ave',
#                'Essington Ave',
#                'Fairmount Ave',
#                'Fort Washington Ave',
#                'Frankford Ave',
#                'Germantown Ave',
#                'Grant Ave',
#                'Grays Ave',
#                'Hirst Ave',
#                'Lancaster Ave',
#                'Montgomery Ave',
#                'Mt.Ephraim Ave',
#                'N Olden Ave',
#                'Park Ave',
#                'Parkway Ave',
#                'Pennington Ave',
#                'Pennsylvania Ave',
#                'Penrose Ave',
#                'Philmont Ave',
#                'Rising Sun Ave',
#                'S Clinton Ave',
#                'S Washington Ave',
#                'S. Clinton Ave',
#                'Sharon Ave',
#                'Sloan Ave',
#                'Stenton Ave',
#                'Summit Ave',
#                'Towamencin Ave',
#                'W Chelten Ave',
#                'W Magnolia Ave',
#                'Washington Ave',
#                'West Butler Ave',
#                'West Girard Ave',
#                'West Glenside Ave',
#                'West Huntington Ave',
#                'West Mermaid Lane and Germantown Ave',
#                'West Montgomery Ave',
#                'West Trenton Ave'},
#               'Ave.': {'Aramingo Ave.',
#                'Baltimore Ave.',
#                'Bonny Brook Ave.',
#                'East Butler Ave.',
#                'Germantown Ave.',
#                'Morton Ave.',
#                'Station Ave.',
#                'Taylor Ave.',
#                'West Butler Ave.'},
#               'B': {'Salem Ave Building B'},
#               'B2': {'Bristol Pike B2'},
#               'Bigler': {'Bigler'},
#               'Blvd': {'Brookline Blvd',
#                'Centennial Blvd',
#                'Floral Vale Blvd',
#                'Garden Gold Blvd',
#                'Garden Golf Blvd',
#                'Hearthstone Blvd',
#                'Nassau Park Blvd',
#                'Nassau Parl Blvd',
#                'S Christopher Columbus Blvd',
#                'Shannondell Blvd',
#                'W Cuthbert Blvd'},
#               'Blvd.': {'Brookline Blvd.'},
#               'Broadway': {'373 North Broadway',
#                'North Broadway',
#                'South Broadway'},
#               'Brown': {'N 37th & Brown'},
#               'Bypass': {'Pemberton Bypass'},
#               'C': {'Aramingo Ave #C'},
#               'Center': {'Town Center'},
#               'Chestnut': {'Chestnut'},
#               'Chippendale': {'Chippendale'},
#               'Cir': {'Woodfield Cir'},
#               'Circle': {'College Circle',
#                'Crestview Circle',
#                'Falcon Circle',
#                'Franklin Mills Circle',
#                'Glenn Circle',
#                'Hanby Circle',
#                'Harrow Circle',
#                'Nolen Circle',
#                'Paine Circle',
#                'Shirley Circle',
#                'Station Circle',
#                'Tara Circle',
#                'Thunder Circle',
#                'Veterans Circle',
#                'Wynnedale Circle'},
#               'Close': {'Heaver Close'},
#               'Cricket': {'Cricket'},
#               'Croft': {'Kings Croft'},
#               'Crossing': {'Harpers Crossing', 'Painters Crossing'},
#               'Ct': {'Portsmouth Ct'},
#               'D102': {'Henry Ave #D102'},
#               'Dr': {'2515 Metropolitan Dr',
#                'Deerpath Dr',
#                'Kendarbren Dr',
#                'Merrill Lynch Dr',
#                'Revere Dr',
#                "Tommy's Meadow Dr"},
#               'E': {'NJ-70 E'},
#               'East': {'Cabot Boulevard East',
#                'Clementon Road East',
#                'E High Street East',
#                'High Street East',
#                'Kings Highway East',
#                'Lincoln Drive East',
#                'Marlton Pike East',
#                'North Independence Mall East',
#                'North Independence Ml East',
#                'Route 38 East',
#                'South Independence Mall East'},
#               'Extension': {'Spruce Street Extension',
#                'Washington Street Extension'},
#               'Floor': {'Race Street 2nd Floor'},
#               'Front': {'S Front'},
#               'Garden': {'Spring Garden'},
#               'Greene': {'Greene', 'Township Greene'},
#               'Haverford': {'Haverford'},
#               'Highway': {'East Lincoln Highway',
#                'Harding Highway',
#                'Kings Highway',
#                'Lincoln Highway',
#                'North Kings Highway',
#                'Old Lincoln Highway'},
#               'Hook': {'Calcon Hook'},
#               'Hutchinson': {'North Hutchinson'},
#               'Hwy': {'Harding Hwy', 'Lincoln Hwy'},
#               'Ln': {'Patricia Ln', 'Simpkins Ln'},
#               'Mallon': {'Mallon'},
#               'Manor': {'Brynwood Manor'},
#               'Maple': {'South Maple'},
#               'Market': {'Market'},
#               'Master': {'15th and Master'},
#               'Moore': {'Cecil B. Moore'},
#               'N': {'B Route 73 N'},
#               'NJ-73': {'NJ-73'},
#               'Nixon': {'Shawmont & Nixon'},
#               'North': {'Delsea Drive North',
#                'Kings Highway North',
#                'Lakeview Drive North'},
#               'PA': {'Baltimore Pike, Springfield, PA',
#                'E Lincoln HwyLanghorne, PA',
#                'E. Lincoln Highway Langhore, PA',
#                'Saxer Ave, Springfield, PA'},
#               'PA.': {'Trenton Rd - Levittown, PA.'},
#               'PIke': {'Princeton PIke'},
#               'Park': {'Falsoa Park', 'Narbrook Park'},
#               'Parrish': {'Parrish'},
#               'Pike': {'2nd Street Pike',
#                'Baltimore Pike',
#                'Bethlehem Pike',
#                'Black Horse Pike',
#                'Bridgeton Pike',
#                'Bridgetown Pike',
#                'Bristol Pike',
#                'Brunswick Pike',
#                'Butler Pike',
#                'Concord Pike',
#                'DeKalb Pike',
#                'East Germantown Pike',
#                'East Ridge Pike',
#                'Germantown Pike',
#                'Huntingdon Pike',
#                'Limekiln Pike',
#                'Mantua Pike',
#                'Marlton Pike',
#                'North Bethlehem Pike',
#                'Philadelphia Pike',
#                'Princeton Pike',
#                'Ridge Pike',
#                'S Bethlehem Pike',
#                'S Black Horse Pike',
#                'Second Street Pike',
#                'Skippack Pike',
#                'South Bethlehem Pike',
#                'Sumneytown Pike',
#                'W Germantown Pike',
#                'W Ridge Pike',
#                'West Baltimore Pike',
#                'West Chester Pike',
#                'West Dekalb Pike',
#                'West Germantown Pike',
#                'West Marlton Pike',
#                'West Point Pike',
#                'West Ridge Pike',
#                'White Horse Pike',
#                'Wilmington Pike'},
#               'Plaza': {'Dothan Plaza', 'Yorktown Plaza'},
#               'Preston': {'N Preston'},
#               'ROAD': {'DAVISVILLE ROAD',
#                'TERWOOD ROAD',
#                'TOWNSHIP LINE ROAD'},
#               'Rd': {'22 Centerton Rd',
#                '24 Centerton Rd',
#                '40 Centerton Rd',
#                '50 Centerton Rd',
#                '52 Centerton Rd',
#                '58 Centerton Rd',
#                '62 Centerton Rd',
#                '66 Centerton Rd',
#                '70 Centerton Rd',
#                'Abrams Mill Rd',
#                'Almshouse Rd',
#                'Anderson Rd',
#                "Arney's Mount Rd",
#                'Barren Hill Rd',
#                'Briarwood Rd',
#                'Bristol Rd',
#                'Byberry Rd',
#                'Calcon Hook Rd',
#                'Church Rd',
#                'Clements Bridge Rd',
#                'Conestoga Rd',
#                'Cross Keys Rd',
#                'Darby Rd',
#                'Deptford Center Rd',
#                'Dilworthtown Rd',
#                'Durham Rd',
#                'E County Line Rd',
#                'Easton Rd',
#                'Edison Furlong Rd',
#                'Evesham Rd',
#                'Grove Rd',
#                'Haddonfield Rd',
#                'Hulmeville Rd',
#                'Hurffville  Rd',
#                'Hurffville Rd',
#                'Kimberton Rd',
#                'King Rd',
#                'Lincoln Mill Rd',
#                'Meetinghouse Rd',
#                'N Providence Rd',
#                'New Falls Rd',
#                'Old Cuthbert Rd',
#                'Russell Mill Rd',
#                'S Easton Rd',
#                'Schuylkill Rd',
#                'South Easton Rd',
#                'Sproul Rd',
#                'Stokes Rd',
#                'Valley Rd',
#                'W Bristol Rd',
#                'Woodmount Rd',
#                'York Rd'},
#               'Rd.': {'Clements Bridge Rd.',
#                'Kagey Rd.',
#                'N. Lewis Rd.',
#                'North Lewis Rd.',
#                'S. Chester Rd.',
#                'W. Street Rd.',
#                'Wistar Rd.',
#                'York Rd.'},
#               'Reno': {'North 50th Street & Reno'},
#               'Run': {'Autumn River Run', 'Pheasant Run'},
#               'ST': {'S 6TH ST'},
#               'Salina': {'Salina'},
#               'Sheffield': {'Sheffield'},
#               'Sloan': {'Sloan'},
#               'South': {'Lakeview Drive South',
#                'Route 130 South',
#                'Steel Road South'},
#               'Spruce': {'Spruce'},
#               'Sstreet': {'South 9th Sstreet'},
#               'St': {'46th and Market St',
#                '507 E Tulpehocken St',
#                'Baring St',
#                'Bush St',
#                'Carson St',
#                'Center St',
#                'Chestnut St',
#                'Coates St',
#                'Cooper St',
#                'Dekalb St',
#                'Dickinson St',
#                'E Front St',
#                'E Hampton St',
#                'E Hector St',
#                'E Penn St',
#                'E State St',
#                'E Wingohocking St',
#                'E. Passyunk Ave and Kauffman St',
#                'Federal St',
#                'Front St & Tasker St',
#                'Green St',
#                'Johnston St',
#                'Market St',
#                'McKean St',
#                'N 3rd St',
#                'N 4th St',
#                'N 5th St',
#                'N 6th St',
#                'N Broad St',
#                'N Gratz St',
#                'N Main St',
#                'North Broad St',
#                'North Front St',
#                'Quarry St',
#                'Race St',
#                'Ranstead St',
#                'Rhawn St',
#                'S 19th St',
#                'S 20th St',
#                'S 22nd St',
#                'S 24th St',
#                'S 28th St',
#                'S 3rd St',
#                'S 41st St',
#                'S 47th St',
#                'S 4th St',
#                'S 50th St',
#                'S Broad St',
#                'S Main St',
#                'S Norwood St',
#                'S Warren St',
#                'South 40th St',
#                'South Bancroft St',
#                'South St',
#                'South St Bernard St',
#                'Spring Garden St',
#                'St John St',
#                'Starr St',
#                'Swede St',
#                'W Ritner St',
#                'W State St',
#                'Walnut St',
#                'Washington St',
#                'West Main St'},
#               'St.': {'12th St.',
#                'Almond St.',
#                'Diamond St.',
#                'E. State St.',
#                'Mt. Pleasant Ave, Devon St, Sprague St.',
#                'N 24th St.',
#                'S. 15th St.',
#                'S. 40th St.',
#                'South Broad St.',
#                'W. State St.'},
#               'Steet': {'South 18th Steet'},
#               'Stiles': {'16th and Stiles'},
#               'StreetPhiladelphia': {'117 South 18th StreetPhiladelphia'},
#               'Streets': {'North 13th and Brown Streets'},
#               'Sts.': {'1st and Seneca Sts.'},
#               'Sycamore': {'North Sycamore'},
#               'Ter': {'Greenview Ter'},
#               'Terrace': {'Alfa Terrace',
#                'Beverly Terrace',
#                'Dothan Terrace',
#                'Elm Terrace',
#                'Lakeview Terrace',
#                'McClenachan Terrace'},
#               'Thompson': {'Sletcher and Thompson'},
#               'US-130': {'US-130'},
#               'Vine': {'12th and Vine'},
#               'W': {'NJ 70 W', 'State Route 70 W'},
#               'W5': {'Presidential Blvd, Ste W5'},
#               'Walk': {'Hamilton Walk',
#                'Liacouras Walk',
#                'Locust Walk',
#                'Polett Walk',
#                'Woodland Walk'},
#               'Warminster': {'Warminster'},
#               'Warren': {'Warren'},
#               'Way': {'Applied Card Way',
#                'Arbor Way',
#                'Azalea Way',
#                'Bellows Way',
#                'Braxton Way',
#                'Commons Way',
#                'Eagle Way',
#                'Foundry Way',
#                'Freedoms Way',
#                'Green Valley Way',
#                'Janton Way',
#                'Jennifer Way',
#                'Johnnys Way',
#                'Lafrance Way',
#                'Lantern Way',
#                'Lucretia Mott Way',
#                'Maple Way',
#                'Mather Way',
#                'Nina Way',
#                'Plaza Way',
#                'Rock Way',
#                'Scout Way',
#                'Technology Way',
#                'Triumphe Way',
#                "Veteran's Way",
#                'Westtown Way',
#                'Winston Way',
#                'Woodview Way'},
#               'West': {'Cabot Boulevard West',
#                'Marlton Pike West',
#                'North Independence Mall West',
#                'Old Marlton Pike West'},
#               'al': {'pullen al'},
#               'ave': {'Ridge ave',
#                'and 1891 brunswick ave',
#                'hillcrest ave',
#                'michigan ave'},
#               'avenue': {'Ohio avenue'},
#               'drive': {'Bucks Town drive'},
#               'ext': {'brunswick ave ext'},
#               'king': {'West king'},
#               'lane': {'country club lane'},
#               'rd': {'Cricket rd', 'Lawrenceville rd'},
#               'road': {'Morehall road', 'Newtown-Langhorne road'},
#               'south': {'Route 130 south'},
#               'st': {'Main st',
#                'centre st',
#                'clay st',
#                'e front st',
#                'e state st',
#                'jackson st',
#                'livingston st',
#                'market st',
#                'mercer st',
#                'pear st',
#                's 3rd st',
#                's broad st',
#                's montgomery st',
#                's stockton st',
#                's warren st',
#                'st',
#                'w state st'},
#               'st.': {'E. State st.'},
#               'street': {'9th street',
#                'Broad street',
#                'East ontario street',
#                'Westmoreland street',
#                'chestnut street',
#                'tilton street'},
#               'susquahana': {'thompson and susquahana'},
#               'way': {'mortgage way'}}),
#  defaultdict(set,
#              {'080033': {'080033'},
#               '08033-2001': {'08033-2001'},
#               '080343': {'080343'},
#               '08062-4446': {'08062-4446'},
#               '0815': {'0815'},
#               '1713': {'1713'},
#               '1719': {'1719'},
#               '1723': {'1723'},
#               '189440': {'189440'},
#               '19010-3224': {'19010-3224'},
#               '19030-4005': {'19030-4005'},
#               '19041-1228': {'19041-1228'},
#               '19072b1393e': {'19072b1393e'},
#               '19073-3299': {'19073-3299'},
#               '19087-3696': {'19087-3696'},
#               '19096-9998': {'19096-9998'},
#               '19104-2989': {'19104-2989'},
#               u'19147\u200e': {u'19147\u200e'},
#               '19148-9996': {'19148-9996'},
#               '19154-3131': {'19154-3131'},
#               '19312-1239': {'19312-1239'},
#               '19803-9997': {'19803-9997'},
#               '519 Stokes Rd # A Medford, NJ 08055': {'519 Stokes Rd # A Medford, NJ 08055'},
#               '601 Stokes Road Medford, NJ 08055': {'601 Stokes Road Medford, NJ 08055'},
#               '617 Stokes Rd # 10 Medford, NJ 08055': {'617 Stokes Rd # 10 Medford, NJ 08055'},
#               '617 Stokes Road Medford, NJ 08055': {'617 Stokes Road Medford, NJ 08055'},
#               '620 Stokes Rd # EMedford, NJ 08055': {'620 Stokes Rd # EMedford, NJ 08055'},
#               '7500': {'7500'},
#               '9406': {'9406'},
#               'NJ 08033': {'NJ 08033'},
#               'NJ 08083': {'NJ 08083'},
#               'NJ 08107': {'NJ 08107'},
#               'PA': {'PA'},
#               'PA 19153': {'PA 19153'},
#               'PA 19428': {'PA 19428'},
#               'PA 19446': {'PA 19446'},
#               'Philadelphia, PA 19134': {'Philadelphia, PA 19134'}}))

# %%
streettype_dict, postcode_dict = audit(philly)

# make the values returned easy to read:

from pprint import pprint

print "\n\n Street types  \n"

for key, value in streettype_dict.items():
    print key
    pprint(value)

print "\n\n Postcodes  \n"
for key, value in postcode_dict.items():
    print key
    pprint(value)
# Out:
#  Street types
#
# Walk
# set(['Locust Walk'])
# Croft
# set(['Kings Croft'])
# Ln
# set(['Simpkins Ln'])
# West
# set(['North Independence Mall West'])
# St.
# set(['Diamond St.', 'South Broad St.'])
# 70
# set(['State Route 70', 'US 70'])
# al
# set(['pullen al'])
# Haverford
# set(['Haverford'])
# Rd
# set(["Arney's Mount Rd",
#      'Clements Bridge Rd',
#      'Conestoga Rd',
#      'Cross Keys Rd',
#      'Darby Rd',
#      'Easton Rd',
#      'Hurffville Rd'])
# 111
# set(['South Clinton Avenue Ste. 111'])
# Way
# set(['Azalea Way',
#      'Bellows Way',
#      'Green Valley Way',
#      'Janton Way',
#      'Jennifer Way',
#      'Lafrance Way',
#      'Lucretia Mott Way',
#      'Mather Way',
#      'Plaza Way',
#      'Winston Way',
#      'Woodview Way'])
# Thompson
# set(['Sletcher and Thompson'])
# ave
# set(['Ridge ave', 'michigan ave'])
# Circle
# set(['College Circle',
#      'Crestview Circle',
#      'Falcon Circle',
#      'Hanby Circle',
#      'Nolen Circle',
#      'Shirley Circle',
#      'Tara Circle',
#      'Wynnedale Circle'])
# East
# set(['Clementon Road East',
#      'High Street East',
#      'Lincoln Drive East',
#      'Marlton Pike East'])
# avenue
# set(['Ohio avenue'])
# Highway
# set(['East Lincoln Highway', 'Lincoln Highway', 'North Kings Highway'])
# Chestnut
# set(['Chestnut'])
# Rd.
# set(['Kagey Rd.'])
# North
# set(['Delsea Drive North', 'Lakeview Drive North'])
# Manor
# set(['Brynwood Manor'])
# Park
# set(['Narbrook Park'])
# 1
# set(['Sansom St #1'])
# PA
# set(['Baltimore Pike, Springfield, PA'])
# StreetPhiladelphia
# set(['117 South 18th StreetPhiladelphia'])
# Hwy
# set(['Harding Hwy'])
# Dr
# set(["Tommy's Meadow Dr"])
# 452
# set(['Pennel Road; Pennsylvania Route 452'])
# Pike
# set(['Baltimore Pike',
#      'Bethlehem Pike',
#      'Brunswick Pike',
#      'Butler Pike',
#      'Concord Pike',
#      'East Germantown Pike',
#      'Limekiln Pike',
#      'Marlton Pike',
#      'Princeton Pike',
#      'Sumneytown Pike',
#      'West Chester Pike',
#      'West Germantown Pike',
#      'West Ridge Pike',
#      'White Horse Pike'])
# Ave.
# set(['Bonny Brook Ave.', 'Morton Ave.'])
# Center
# set(['Town Center'])
# Extension
# set(['Spruce Street Extension'])
# Plaza
# set(['Dothan Plaza'])
# Bigler
# set(['Bigler'])
# St
# set(['Cooper St',
#      'E Hampton St',
#      'E State St',
#      'Green St',
#      'N 4th St',
#      'N Main St',
#      'Race St',
#      'Rhawn St',
#      'S 47th St',
#      'S Broad St',
#      'Spring Garden St'])
# Cir
# set(['Woodfield Cir'])
# 73
# set(['State Route 73'])
# Ave
# set(['Chester Ave',
#      'Cottman Ave',
#      'Essington Ave',
#      'Fort Washington Ave',
#      'Germantown Ave',
#      'Grant Ave',
#      'Lancaster Ave',
#      'Montgomery Ave',
#      'Philmont Ave',
#      'S Clinton Ave',
#      'Sharon Ave',
#      'Summit Ave'])
# Crossing
# set(['Harpers Crossing'])
# Run
# set(['Autumn River Run', 'Pheasant Run'])
# South
# set(['Lakeview Drive South'])
# 38
# set(['Route 38', 'State Route 38'])
# Vine
# set(['12th and Vine'])
# Alley
# set(['Elfreths Alley'])
# st
# set(['clay st',
#      'e front st',
#      'jackson st',
#      'mercer st',
#      'pear st',
#      's broad st',
#      's stockton st',
#      'w state st'])
# ext
# set(['brunswick ave ext'])
# Terrace
# set(['Alfa Terrace', 'Dothan Terrace', 'Elm Terrace', 'Lakeview Terrace'])
# Blvd
# set(['Garden Gold Blvd',
#      'Hearthstone Blvd',
#      'S Christopher Columbus Blvd',
#      'W Cuthbert Blvd'])
# Broadway
# set(['South Broadway'])
# south
# set(['Route 130 south'])
#
#
#  Postcodes
#
# 601 Stokes Road Medford, NJ 08055
# set(['601 Stokes Road Medford, NJ 08055'])
# 1719
# set(['1719'])
# 0815
# set(['0815'])

# %%
#cleaning dirty street names in our audit
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Pike", "Way"]

mapping = { "St": "Street",
            "St.": "Street",
            "st": "Street",
            "st.": "Street",
            "Dr.": "Drive",
            "Rd": "Road",
            "avenue": "Avenue",
            "road": "Road",
            "street": "Street",
            "way": "Way",
            "Blvd.": "Boulevard",
            "Rd.": "Road",
            "Ave": "Avenue",
            }

def update_name(name, mapping):
    m = street_type_re.search(name)
    other_street_types = []
    if m.group() not in expected:
        if m.group() in mapping.keys():
            name = re.sub(m.group(), mapping[m.group()], name)
        else:
            other_street_types.append(street_type)
    return name

def update_postcode(postcode):
    clean_postcode = re.findall(r'^[A-Z]{2} (\d{5})$', postcode)
    # if your regex does find a match then it will return a non-empty list:
    if clean_postcode:
        # only then do you select the list item that you want to return
        cleaned_postcode = clean_postcode[0]
        return clean_postcode
    # otherwise, if regex returns an empty list:
    else:
        # return the original value
        return postcode

# %%
OSM_PATH = SAMPLE_FILE

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

#SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    #way_tag = {}
    tags = []  # Handle secondary tags the same way for both node and way elements
    #node_tag = {}
    id_list = []

    if element.tag == 'node':
        for attrib in element.attrib:
            if attrib in NODE_FIELDS:
                node_attribs[attrib] = element.attrib[attrib]
        for child in element:
            node_tag = {}
            if PROBLEMCHARS.match(child.attrib["k"]):
                continue
            elif LOWER_COLON.match(child.attrib["k"]):
                node_tag["type"] = child.attrib["k"].split(":",2)[0]
                node_tag["key"] = child.attrib["k"].split(":",2)[1]
                node_tag["id"] = element.attrib["id"]
                if child.attrib['k'] == 'addr:postcode':
                    node_tag["value"] = update_postcode(child.attrib["v"])
                # otherwise, don't clean:
                else:
                    node_tag["value"] = child.attrib["v"]
                #tags.append(node_tag)
                #node_tag["value"] = child.attrib["v"]
                tags.append(node_tag)
            
            else:
                node_tag["type"] = "regular"
                node_tag["key"] = child.attrib["k"]
                node_tag["id"] = element.attrib["id"]
                if child.attrib['k'] == 'addr:street':
                    node_tag["value"] = update_name(child.attrib["v"])
                else:
                    node_tag["value"] = child.attrib["v"]
                node_tag["value"] = child.attrib["v"]
                #print node_tag
                tags.append(node_tag)
    elif element.tag == 'way':
        for attrib in element.attrib:
            if attrib in WAY_FIELDS:
                way_attribs[attrib] = element.attrib[attrib]
        for child in element:
            way_node = {}
            way_tag = {}
            if child.tag == "nd":
                if element.attrib["id"] not in id_list:
                    i=0
                    id_list.append(element.attrib["id"])
                    way_node["id"] = element.attrib["id"]
                    way_node["node_id"] = child.attrib["ref"]
                    way_node["position"] = i
                    #print way_node
                    way_nodes.append(way_node.copy())
                else:
                    i=i+1
                    way_node["id"] = element.attrib["id"]
                    way_node["node_id"] = child.attrib["ref"]
                    way_node["position"] = i
                    way_nodes.append(way_node.copy())
            if child.tag == "tag":
                if PROBLEMCHARS.match(child.attrib["k"]):
                    continue
                elif LOWER_COLON.match(child.attrib["k"]):
                    way_tag["type"] = child.attrib["k"].split(":",1)[0]
                    way_tag["key"] = child.attrib["k"].split(":",1)[1]
                    way_tag["id"] = element.attrib["id"]
                    way_tag["value"] = child.attrib["v"]
                    tags.append(way_tag.copy())
            
                else:
                    way_tag["type"] = "regular"
                    way_tag["key"] = child.attrib["k"]
                    way_tag["id"] = element.attrib["id"]
                    way_tag["value"] = child.attrib["v"]
                    tags.append(way_tag.copy())
        #pprint.pprint(tags)
    if element.tag == 'node':
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %%
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
        codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])
'''

if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)
'''
# Out:
# "\n\nif __name__ == '__main__':\n    # Note: Validation is ~ 10X slower. For the project consider using a small\n    # sample of the map when validating.\n    process_map(OSM_PATH, validate=True)\n"

# %%
shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular')

# %%
process_map(philly, validate=False)
